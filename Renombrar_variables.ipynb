# %%
# Tras la ejecución de "Codificación_numérica.ipynb"

# %%
# Librerías básicas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from dython.nominal import associations

# %%
# INTRODUCIR LA RUTA DONDE SE HAYA GUARDADO EL ARCHIVO
# El archivo guardado se llama "Dataset_Cod_Python"
df = pd.read_excel('INTRODUCIR_RUTA_ARCHIVO_GUARDADO/Dataset_Final.xlsx')

# %%
df_bis = df

# %%
# Variables renombradas para evitar problemas en el funcionamiento de los algoritmos

df_bis.rename(columns={'destination_No Urgent Place': 'destination.NoUrgentPlace'}, inplace=True)
df_bis.rename(columns={'destination_Urgent Place': 'destination.UrgentPlace'}, inplace=True)

df_bis.rename(columns={'passanger_Alone': 'passanger.Alone'}, inplace=True)
df_bis.rename(columns={'passanger_Friend(s)': 'passanger.Friends'}, inplace=True)
df_bis.rename(columns={'passanger_Kid(s)': 'passanger.Kids'}, inplace=True)
df_bis.rename(columns={'passanger_Partner': 'passanger.Partner'}, inplace=True)

df_bis.rename(columns={'weather_Adverse Climatology': 'weather.AdverseClimatology'}, inplace=True)
df_bis.rename(columns={'weather_Sunny': 'weather.Sunny'}, inplace=True)

df_bis.rename(columns={'temperature_13': 'temperature.13'}, inplace=True)
df_bis.rename(columns={'temperature_27': 'temperature.27'}, inplace=True)
df_bis.rename(columns={'temperature_m1': 'temperature.m1'}, inplace=True)

df_bis.rename(columns={'time_10AM': 'time.10AM'}, inplace=True)
df_bis.rename(columns={'time_10PM': 'time.10PM'}, inplace=True)
df_bis.rename(columns={'time_2PM': 'time.2PM'}, inplace=True)
df_bis.rename(columns={'time_6PM': 'time.6PM'}, inplace=True)
df_bis.rename(columns={'time_7AM': 'time.7AM'}, inplace=True)

df_bis.rename(columns={'coupon_Bar': 'coupon.Bar'}, inplace=True)
df_bis.rename(columns={'coupon_Carry out & Take away': 'coupon.CarryOutTakeAway'}, inplace=True)
df_bis.rename(columns={'coupon_Coffee House': 'coupon.CoffeeHouse'}, inplace=True)
df_bis.rename(columns={'coupon_Restaurant(<20)': 'coupon.RestaurantBelow20'}, inplace=True)
df_bis.rename(columns={'coupon_Restaurant(20-50)': 'coupon.RestaurantBetw2050'}, inplace=True)

df_bis.rename(columns={'expiration_1d': 'expiration.1d'}, inplace=True)
df_bis.rename(columns={'expiration_2h': 'expiration.2h'}, inplace=True)

df_bis.rename(columns={'gender_Female': 'gender.Female'}, inplace=True)
df_bis.rename(columns={'gender_Male': 'gender.Male'}, inplace=True)

df_bis.rename(columns={'age_50plus': 'age.50plus'}, inplace=True)
df_bis.rename(columns={'age_Adult': 'age.Adult'}, inplace=True)
df_bis.rename(columns={'age_Youth': 'age.Youth'}, inplace=True)
df_bis.rename(columns={'age_below21': 'age.below21'}, inplace=True)

df_bis.rename(columns={'maritalStatus_Divorced': 'maritalStatus.Divorced'}, inplace=True)
df_bis.rename(columns={'maritalStatus_Married partner': 'maritalStatus.MarriedPartner'}, inplace=True)
df_bis.rename(columns={'maritalStatus_Single': 'maritalStatus.Single'}, inplace=True)
df_bis.rename(columns={'maritalStatus_Unmarried partner': 'maritalStatus.UnmarriedPartner'}, inplace=True)
df_bis.rename(columns={'maritalStatus_Widowed': 'maritalStatus.Widowed'}, inplace=True)

df_bis.rename(columns={'has_children_No': 'hasChildren.No'}, inplace=True)
df_bis.rename(columns={'has_children_Yes': 'hasCchildren.Yes'}, inplace=True)

df_bis.rename(columns={'education_AssociatesDegree': 'education.AssociatesDegree'}, inplace=True)
df_bis.rename(columns={'education_BachelorsDegree': 'education.BachelorsDegree'}, inplace=True)
df_bis.rename(columns={'education_GraduateDegree': 'education.GraduateDegree'}, inplace=True)
df_bis.rename(columns={'education_HighSchoolGraduate': 'education.HighSchoolGraduate'}, inplace=True)
df_bis.rename(columns={'education_SomeCollegeNoDegree': 'education.SomeCollegeNoDegree'}, inplace=True)
df_bis.rename(columns={'education_SomeHighSchool': 'education.SomeHighSchool'}, inplace=True)

df_bis.rename(columns={'occupation_Employee': 'occupation.Employee'}, inplace=True)
df_bis.rename(columns={'occupation_Retired': 'occupation.Retired'}, inplace=True)
df_bis.rename(columns={'occupation_Student': 'occupation.Student'}, inplace=True)
df_bis.rename(columns={'occupation_Unemployed': 'occupation.Unemployed'}, inplace=True)

df_bis.rename(columns={'income_12500_24999': 'income.12500y24999'}, inplace=True)
df_bis.rename(columns={'income_25000_37499': 'income.25000y37499'}, inplace=True)
df_bis.rename(columns={'income_37500_49999': 'income.37500y49999'}, inplace=True)
df_bis.rename(columns={'income_50000_62499': 'income.50000y62499'}, inplace=True)
df_bis.rename(columns={'income_62500_74999': 'income.62500y74999'}, inplace=True)
df_bis.rename(columns={'income_75000_87499': 'income.75000y87499'}, inplace=True)
df_bis.rename(columns={'income_87500_99999': 'income.87500y99999'}, inplace=True)
df_bis.rename(columns={'income_below12500': 'income.below12500'}, inplace=True)
df_bis.rename(columns={'income_plus100000': 'income.plus100000'}, inplace=True)

df_bis.rename(columns={'Bar_1_3': 'Bar.1to3'}, inplace=True)
df_bis.rename(columns={'Bar_4_8': 'Bar.4to8'}, inplace=True)
df_bis.rename(columns={'Bar_gt8': 'Bar.gt8'}, inplace=True)
df_bis.rename(columns={'Bar_less1': 'Bar.less1'}, inplace=True)
df_bis.rename(columns={'Bar_never': 'Bar.never'}, inplace=True)

df_bis.rename(columns={'CoffeeHouse_1_3': 'CoffeeHouse.1to3'}, inplace=True)
df_bis.rename(columns={'CoffeeHouse_4_8': 'CoffeeHouse.4to8'}, inplace=True)
df_bis.rename(columns={'CoffeeHouse_gt8': 'CoffeeHouse.gt8'}, inplace=True)
df_bis.rename(columns={'CoffeeHouse_less1': 'CoffeeHouse.less1'}, inplace=True)
df_bis.rename(columns={'CoffeeHouse_never': 'CoffeeHouse.never'}, inplace=True)

df_bis.rename(columns={'CarryAway_1_3': 'CarryAway.1to3'}, inplace=True)
df_bis.rename(columns={'CarryAway_4_8': 'CarryAway.4to8'}, inplace=True)
df_bis.rename(columns={'CarryAway_gt8': 'CarryAway.gt8'}, inplace=True)
df_bis.rename(columns={'CarryAway_less1': 'CarryAway.less1'}, inplace=True)
df_bis.rename(columns={'CarryAway_never': 'CarryAway.never'}, inplace=True)

df_bis.rename(columns={'RestaurantLessThan20_1_3': 'RestaurantLessThan20.1to3'}, inplace=True)
df_bis.rename(columns={'RestaurantLessThan20_4_8': 'RestaurantLessThan20.4to8'}, inplace=True)
df_bis.rename(columns={'RestaurantLessThan20_gt8': 'RestaurantLessThan20.gt8'}, inplace=True)
df_bis.rename(columns={'RestaurantLessThan20_less1': 'RestaurantLessThan20.less1'}, inplace=True)
df_bis.rename(columns={'RestaurantLessThan20_never': 'RestaurantLessThan20.never'}, inplace=True)

df_bis.rename(columns={'Restaurant20To50_1_3': 'Restaurant20To50.1to3'}, inplace=True)
df_bis.rename(columns={'Restaurant20To50_4_8': 'Restaurant20To50.4to8'}, inplace=True)
df_bis.rename(columns={'Restaurant20To50_gt8': 'Restaurant20To50.gt8'}, inplace=True)
df_bis.rename(columns={'Restaurant20To50_less1': 'Restaurant20To50.less1'}, inplace=True)
df_bis.rename(columns={'Restaurant20To50_never': 'Restaurant20To50.never'}, inplace=True)

df_bis.rename(columns={'direction_same_No': 'directionSame.No'}, inplace=True)
df_bis.rename(columns={'direction_same_Yes': 'directionSame.Yes'}, inplace=True)

df_bis.rename(columns={'Y_No': 'Y.No'}, inplace=True)
df_bis.rename(columns={'Y_Yes': 'Y.Yes'}, inplace=True)

df_bis.rename(columns={'time_toCoupon_FarAway': 'timeToCoupon.FarAway'}, inplace=True)
df_bis.rename(columns={'time_toCoupon_Medium': 'timeToCoupon.Medium'}, inplace=True)
df_bis.rename(columns={'time_toCoupon_Nearly': 'timeToCoupon.Nearly'}, inplace=True)

# %%
# INTRODUCIR RUTA PARA GUARDAR "Dataset_Dummies_Final.xlsx"
ruta_archivo = 'INTRODUCIR_RUTA_PARA_GUARDAR_ARCHIVO/Dataset_Dummies_Final.xlsx'

# %%
df_bis.to_excel(ruta_archivo, index=False, engine='xlsxwriter')
